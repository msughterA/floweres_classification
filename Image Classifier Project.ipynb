# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
# Imports here
# Check torch version and CUDA status if GPU is enabled.
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.0.1
# True

# %%
# Imports here
from torchvision import datasets, transforms, models
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision.transforms.functional import to_pil_image
import matplotlib.pyplot as plt
from collections import OrderedDict

# %%
# !wget 'https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz'
# !unlink flowers
# !mkdir flowers && tar -xzf flower_data.tar.gz -C flowers

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
# The train transforms would inlcude some augmentations as the dataset seems to be small in size
train_transforms = transforms.Compose([
    transforms.RandomRotation(30),
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(
    [0.485,0.456,0.406],
    [0.229,0.224,0.225]    
    )
])
# The validation dataset should not contain the augmentations
valid_transforms = transforms.Compose([
    transforms.Resize(255),
    transforms.CenterCrop(244),
    transforms.ToTensor(),
    transforms.Normalize(
    [0.485,0.456,0.406],
    [0.229,0.224,0.225]    
    )
])
# The test dataset should not contain the augmentations
test_transforms = transforms.Compose([
    transforms.Resize(255),
    transforms.CenterCrop(244),
    transforms.ToTensor(),
    transforms.Normalize(
    [0.485,0.456,0.406],
    [0.229,0.224,0.225]    
    )
])
# TODO: Load the datasets with ImageFolder
train_dataset = datasets.ImageFolder(train_dir,transform=train_transforms) 
valid_dataset = datasets.ImageFolder(valid_dir,transform=valid_transforms) 
test_dataset = datasets.ImageFolder(test_dir,transform=test_transforms) 

# TODO: Using the image datasets and the trainforms, define the dataloaders
trainloader = DataLoader(train_dataset,shuffle=True,batch_size=64)
validloader = DataLoader(valid_dataset,shuffle=True,batch_size=64)
testloader = DataLoader(test_dataset,shuffle=True)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network
models.resnet101(pretrained=True)
# Out:
# /home/terungwa/anaconda3/envs/ubase/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/terungwa/anaconda3/envs/ubase/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
# TODO: Build and train your network
# load the pretrained network
models.efficientnet_b0(pretrained=True)
# Out:
# Sequential(
#   (0): Dropout(p=0.2, inplace=True)
#   (1): Linear(in_features=1280, out_features=1000, bias=True)
# )

# %%
model = models.efficientnet_b0(pretrained=True)
# Out:
# /home/terungwa/anaconda3/envs/ubase/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# freeze the model parameters so we don't back prop through them
for param in model.parameters():
    param.requires_grad = False

# %%
# Use GPU if it's available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# Create our classifier
classifier = nn.Sequential(
 OrderedDict([
     ('fc1',nn.Linear(1280,256)),
     ('ReLU',nn.ReLU()),
     ('Dropout',nn.Dropout(0.2)),
     ('fc2',nn.Linear(256,150)),
     ('ReLU',nn.ReLU()),
     ('Dropout',nn.Dropout(0.2)),
     ('fc3',nn.Linear(150,102)),
     ('LogSoftmax',nn.LogSoftmax(dim=1))
 ])
)
# Replace the old classifier with out custom classifier
model.classifier = classifier

criterion = nn.NLLLoss()
# train only the classifier classifier
optimizer = torch.optim.Adam(model.classifier.parameters(),lr=0.001)
# push the model to the available accelarator
model.to(device);

# %%
epochs = 10
steps = 0
print_every = 2
running_loss = 0
import time
# print('Training neural network for {} epochs'.format(int(len)))
start_time = time.time()
for e in range(epochs):
    for images, labels in trainloader:
        steps += 1
        images, labels = images.to(device), labels.to(device)
        # get the log probabilities
        logps = model.forward(images)
        # get the loss
        loss = criterion(logps, labels)
        # clear the gradients
        optimizer.zero_grad()
        # calculate the gradients with respect to weights
        loss.backward()
        # take the optimizer step
        optimizer.step()
        # add the loss for the batch
        running_loss += loss.item()
        # check if we should print at this step
        if steps % print_every == 0:
            test_loss = 0
            accuracy = 0
            # put the model in evaluation mode
            model.eval()
            # turn gradient optimization for metric calculations
            with torch.no_grad():
                # run validation
                for images, labels in validloader:
                    images, labels = images.to(device), labels.to(device)
                    logps = model.forward(images)
                    # get the loss for the batch
                    loss = criterion(logps,labels)
                    test_loss += loss.item()
                    # get the actual probabilities
                    ps = torch.exp(logps)
                    top_p, top_class = ps.topk(1,dim=1)
                    equals = top_class == labels.view(*top_class.shape)
                    accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
            model.train()
            print(f"Epoch {e+1}/{epochs}.. "
                  f"Train loss: {running_loss/print_every:.3f}.. "
                  f"Validation loss: {test_loss/len(validloader):.3f}.. "
                  f"Validation accuracy: {accuracy/len(validloader):.3f}")
            # reset running loss 
            running_loss = 0
print("Total running time is {}".format(round(time.time() - start_time)))
# Out:
# Epoch 1/10.. Train loss: 4.616.. Validation loss: 4.596.. Validation accuracy: 0.040
# Epoch 1/10.. Train loss: 4.577.. Validation loss: 4.554.. Validation accuracy: 0.048
# Epoch 1/10.. Train loss: 4.522.. Validation loss: 4.499.. Validation accuracy: 0.069
# Epoch 1/10.. Train loss: 4.515.. Validation loss: 4.439.. Validation accuracy: 0.086
# Epoch 1/10.. Train loss: 4.470.. Validation loss: 4.376.. Validation accuracy: 0.097
# Epoch 1/10.. Train loss: 4.349.. Validation loss: 4.309.. Validation accuracy: 0.112
# Epoch 1/10.. Train loss: 4.340.. Validation loss: 4.246.. Validation accuracy: 0.111
# Epoch 1/10.. Train loss: 4.162.. Validation loss: 4.180.. Validation accuracy: 0.116
# Epoch 1/10.. Train loss: 4.226.. Validation loss: 4.108.. Validation accuracy: 0.133
# Epoch 1/10.. Train loss: 4.053.. Validation loss: 4.025.. Validation accuracy: 0.135
# Epoch 1/10.. Train loss: 4.156.. Validation loss: 3.927.. Validation accuracy: 0.143
# Epoch 1/10.. Train loss: 4.133.. Validation loss: 3.823.. Validation accuracy: 0.179
# Epoch 1/10.. Train loss: 3.963.. Validation loss: 3.720.. Validation accuracy: 0.218
# Epoch 1/10.. Train loss: 3.720.. Validation loss: 3.622.. Validation accuracy: 0.225
# Epoch 1/10.. Train loss: 3.899.. Validation loss: 3.524.. Validation accuracy: 0.231
# Epoch 1/10.. Train loss: 3.736.. Validation loss: 3.410.. Validation accuracy: 0.232
# Epoch 1/10.. Train loss: 3.630.. Validation loss: 3.319.. Validation accuracy: 0.236
# Epoch 1/10.. Train loss: 3.459.. Validation loss: 3.214.. Validation accuracy: 0.255
# Epoch 1/10.. Train loss: 3.426.. Validation loss: 3.083.. Validation accuracy: 0.302
# Epoch 1/10.. Train loss: 3.365.. Validation loss: 2.955.. Validation accuracy: 0.368
# Epoch 1/10.. Train loss: 3.089.. Validation loss: 2.850.. Validation accuracy: 0.388
# Epoch 1/10.. Train loss: 3.026.. Validation loss: 2.739.. Validation accuracy: 0.387
# Epoch 1/10.. Train loss: 3.116.. Validation loss: 2.633.. Validation accuracy: 0.410
# Epoch 1/10.. Train loss: 2.983.. Validation loss: 2.529.. Validation accuracy: 0.431
# Epoch 1/10.. Train loss: 3.078.. Validation loss: 2.439.. Validation accuracy: 0.453
# Epoch 1/10.. Train loss: 2.706.. Validation loss: 2.355.. Validation accuracy: 0.487
# Epoch 1/10.. Train loss: 2.610.. Validation loss: 2.285.. Validation accuracy: 0.507
# Epoch 1/10.. Train loss: 2.525.. Validation loss: 2.216.. Validation accuracy: 0.514
# Epoch 1/10.. Train loss: 2.349.. Validation loss: 2.135.. Validation accuracy: 0.519
# Epoch 1/10.. Train loss: 2.493.. Validation loss: 2.054.. Validation accuracy: 0.528
# Epoch 1/10.. Train loss: 2.402.. Validation loss: 1.956.. Validation accuracy: 0.547
# Epoch 1/10.. Train loss: 2.467.. Validation loss: 1.884.. Validation accuracy: 0.556
# Epoch 1/10.. Train loss: 2.033.. Validation loss: 1.852.. Validation accuracy: 0.543
# Epoch 1/10.. Train loss: 2.537.. Validation loss: 1.840.. Validation accuracy: 0.534
# Epoch 1/10.. Train loss: 2.230.. Validation loss: 1.758.. Validation accuracy: 0.563
# Epoch 1/10.. Train loss: 2.303.. Validation loss: 1.674.. Validation accuracy: 0.604
# Epoch 1/10.. Train loss: 2.148.. Validation loss: 1.651.. Validation accuracy: 0.602
# Epoch 1/10.. Train loss: 2.101.. Validation loss: 1.649.. Validation accuracy: 0.600
# Epoch 1/10.. Train loss: 1.888.. Validation loss: 1.608.. Validation accuracy: 0.589
# Epoch 1/10.. Train loss: 2.050.. Validation loss: 1.554.. Validation accuracy: 0.598
# Epoch 1/10.. Train loss: 1.929.. Validation loss: 1.454.. Validation accuracy: 0.635
# Epoch 1/10.. Train loss: 1.969.. Validation loss: 1.371.. Validation accuracy: 0.657
# Epoch 1/10.. Train loss: 1.787.. Validation loss: 1.351.. Validation accuracy: 0.685
# Epoch 1/10.. Train loss: 2.002.. Validation loss: 1.316.. Validation accuracy: 0.692
# Epoch 1/10.. Train loss: 2.033.. Validation loss: 1.265.. Validation accuracy: 0.701
# Epoch 1/10.. Train loss: 1.657.. Validation loss: 1.230.. Validation accuracy: 0.693
# Epoch 1/10.. Train loss: 1.801.. Validation loss: 1.209.. Validation accuracy: 0.697
# Epoch 1/10.. Train loss: 1.844.. Validation loss: 1.199.. Validation accuracy: 0.700
# Epoch 1/10.. Train loss: 1.863.. Validation loss: 1.196.. Validation accuracy: 0.699
# Epoch 1/10.. Train loss: 1.621.. Validation loss: 1.173.. Validation accuracy: 0.700
# Epoch 1/10.. Train loss: 1.570.. Validation loss: 1.143.. Validation accuracy: 0.716
# Epoch 2/10.. Train loss: 1.402.. Validation loss: 1.150.. Validation accuracy: 0.708
# Epoch 2/10.. Train loss: 1.800.. Validation loss: 1.142.. Validation accuracy: 0.705
# Epoch 2/10.. Train loss: 1.271.. Validation loss: 1.124.. Validation accuracy: 0.706
# Epoch 2/10.. Train loss: 1.538.. Validation loss: 1.116.. Validation accuracy: 0.695
# Epoch 2/10.. Train loss: 1.487.. Validation loss: 1.080.. Validation accuracy: 0.712
# Epoch 2/10.. Train loss: 1.602.. Validation loss: 1.044.. Validation accuracy: 0.727
# Epoch 2/10.. Train loss: 1.542.. Validation loss: 1.032.. Validation accuracy: 0.740
# Epoch 2/10.. Train loss: 1.510.. Validation loss: 1.002.. Validation accuracy: 0.744
# Epoch 2/10.. Train loss: 1.492.. Validation loss: 0.994.. Validation accuracy: 0.750
# Epoch 2/10.. Train loss: 1.300.. Validation loss: 1.019.. Validation accuracy: 0.748
# Epoch 2/10.. Train loss: 1.325.. Validation loss: 1.021.. Validation accuracy: 0.736
# Epoch 2/10.. Train loss: 1.327.. Validation loss: 1.010.. Validation accuracy: 0.739
# Epoch 2/10.. Train loss: 1.566.. Validation loss: 0.981.. Validation accuracy: 0.742
# Epoch 2/10.. Train loss: 1.627.. Validation loss: 0.967.. Validation accuracy: 0.744
# Epoch 2/10.. Train loss: 1.282.. Validation loss: 0.977.. Validation accuracy: 0.736
# Epoch 2/10.. Train loss: 1.525.. Validation loss: 0.969.. Validation accuracy: 0.740
# Epoch 2/10.. Train loss: 1.443.. Validation loss: 0.905.. Validation accuracy: 0.772
# Epoch 2/10.. Train loss: 1.336.. Validation loss: 0.863.. Validation accuracy: 0.783
# Epoch 2/10.. Train loss: 1.139.. Validation loss: 0.869.. Validation accuracy: 0.785
# Epoch 2/10.. Train loss: 1.343.. Validation loss: 0.878.. Validation accuracy: 0.783
# Epoch 2/10.. Train loss: 1.496.. Validation loss: 0.860.. Validation accuracy: 0.792
# Epoch 2/10.. Train loss: 1.077.. Validation loss: 0.830.. Validation accuracy: 0.792
# Epoch 2/10.. Train loss: 1.263.. Validation loss: 0.810.. Validation accuracy: 0.801
# Epoch 2/10.. Train loss: 1.283.. Validation loss: 0.802.. Validation accuracy: 0.798
# Epoch 2/10.. Train loss: 1.368.. Validation loss: 0.796.. Validation accuracy: 0.791
# Epoch 2/10.. Train loss: 1.067.. Validation loss: 0.807.. Validation accuracy: 0.785
# Epoch 2/10.. Train loss: 1.244.. Validation loss: 0.806.. Validation accuracy: 0.793
# Epoch 2/10.. Train loss: 1.113.. Validation loss: 0.788.. Validation accuracy: 0.791
# Epoch 2/10.. Train loss: 1.071.. Validation loss: 0.771.. Validation accuracy: 0.783
# Epoch 2/10.. Train loss: 1.099.. Validation loss: 0.759.. Validation accuracy: 0.792
# Epoch 2/10.. Train loss: 1.283.. Validation loss: 0.751.. Validation accuracy: 0.790
# Epoch 2/10.. Train loss: 1.291.. Validation loss: 0.757.. Validation accuracy: 0.788
# Epoch 2/10.. Train loss: 1.235.. Validation loss: 0.759.. Validation accuracy: 0.784
# Epoch 2/10.. Train loss: 1.066.. Validation loss: 0.756.. Validation accuracy: 0.786
# Epoch 2/10.. Train loss: 1.320.. Validation loss: 0.760.. Validation accuracy: 0.775
# Epoch 2/10.. Train loss: 1.319.. Validation loss: 0.758.. Validation accuracy: 0.787
# Epoch 2/10.. Train loss: 1.093.. Validation loss: 0.746.. Validation accuracy: 0.785
# Epoch 2/10.. Train loss: 1.270.. Validation loss: 0.729.. Validation accuracy: 0.793
# Epoch 2/10.. Train loss: 1.240.. Validation loss: 0.710.. Validation accuracy: 0.800
# Epoch 2/10.. Train loss: 1.029.. Validation loss: 0.702.. Validation accuracy: 0.804
# Epoch 2/10.. Train loss: 1.387.. Validation loss: 0.696.. Validation accuracy: 0.809
# Epoch 2/10.. Train loss: 1.091.. Validation loss: 0.700.. Validation accuracy: 0.807
# Epoch 2/10.. Train loss: 1.221.. Validation loss: 0.706.. Validation accuracy: 0.810
# Epoch 2/10.. Train loss: 0.986.. Validation loss: 0.711.. Validation accuracy: 0.804
# Epoch 2/10.. Train loss: 1.018.. Validation loss: 0.709.. Validation accuracy: 0.804
# Epoch 2/10.. Train loss: 1.412.. Validation loss: 0.688.. Validation accuracy: 0.804
# Epoch 2/10.. Train loss: 1.115.. Validation loss: 0.668.. Validation accuracy: 0.817
# Epoch 2/10.. Train loss: 1.329.. Validation loss: 0.657.. Validation accuracy: 0.833
# Epoch 2/10.. Train loss: 1.002.. Validation loss: 0.676.. Validation accuracy: 0.829
# Epoch 2/10.. Train loss: 0.999.. Validation loss: 0.693.. Validation accuracy: 0.819
# Epoch 2/10.. Train loss: 1.077.. Validation loss: 0.691.. Validation accuracy: 0.814
# Epoch 2/10.. Train loss: 1.183.. Validation loss: 0.677.. Validation accuracy: 0.831
# Epoch 3/10.. Train loss: 1.276.. Validation loss: 0.663.. Validation accuracy: 0.834
# Epoch 3/10.. Train loss: 0.970.. Validation loss: 0.671.. Validation accuracy: 0.826
# Epoch 3/10.. Train loss: 1.236.. Validation loss: 0.656.. Validation accuracy: 0.829
# Epoch 3/10.. Train loss: 1.103.. Validation loss: 0.659.. Validation accuracy: 0.824
# Epoch 3/10.. Train loss: 1.089.. Validation loss: 0.642.. Validation accuracy: 0.832
# Epoch 3/10.. Train loss: 1.188.. Validation loss: 0.648.. Validation accuracy: 0.827
# Epoch 3/10.. Train loss: 0.885.. Validation loss: 0.663.. Validation accuracy: 0.823
# Epoch 3/10.. Train loss: 1.061.. Validation loss: 0.660.. Validation accuracy: 0.816
# Epoch 3/10.. Train loss: 0.920.. Validation loss: 0.662.. Validation accuracy: 0.820
# Epoch 3/10.. Train loss: 0.883.. Validation loss: 0.647.. Validation accuracy: 0.823
# Epoch 3/10.. Train loss: 1.175.. Validation loss: 0.635.. Validation accuracy: 0.826
# Epoch 3/10.. Train loss: 1.009.. Validation loss: 0.621.. Validation accuracy: 0.827
# Epoch 3/10.. Train loss: 0.871.. Validation loss: 0.609.. Validation accuracy: 0.833
# Epoch 3/10.. Train loss: 1.021.. Validation loss: 0.602.. Validation accuracy: 0.831
# Epoch 3/10.. Train loss: 0.901.. Validation loss: 0.586.. Validation accuracy: 0.837
# Epoch 3/10.. Train loss: 0.972.. Validation loss: 0.574.. Validation accuracy: 0.850
# Epoch 3/10.. Train loss: 0.831.. Validation loss: 0.570.. Validation accuracy: 0.844
# Epoch 3/10.. Train loss: 1.073.. Validation loss: 0.569.. Validation accuracy: 0.851
# Epoch 3/10.. Train loss: 0.861.. Validation loss: 0.590.. Validation accuracy: 0.845
# Epoch 3/10.. Train loss: 0.982.. Validation loss: 0.602.. Validation accuracy: 0.848
# Epoch 3/10.. Train loss: 0.907.. Validation loss: 0.604.. Validation accuracy: 0.839
# Epoch 3/10.. Train loss: 1.101.. Validation loss: 0.591.. Validation accuracy: 0.847
# Epoch 3/10.. Train loss: 1.004.. Validation loss: 0.578.. Validation accuracy: 0.841
# Epoch 3/10.. Train loss: 0.876.. Validation loss: 0.574.. Validation accuracy: 0.837
# Epoch 3/10.. Train loss: 0.994.. Validation loss: 0.581.. Validation accuracy: 0.838
# Epoch 3/10.. Train loss: 0.809.. Validation loss: 0.575.. Validation accuracy: 0.841
# Epoch 3/10.. Train loss: 0.817.. Validation loss: 0.560.. Validation accuracy: 0.853
# Epoch 3/10.. Train loss: 1.013.. Validation loss: 0.544.. Validation accuracy: 0.853
# Epoch 3/10.. Train loss: 1.089.. Validation loss: 0.532.. Validation accuracy: 0.865
# Epoch 3/10.. Train loss: 1.024.. Validation loss: 0.527.. Validation accuracy: 0.870
# Epoch 3/10.. Train loss: 0.995.. Validation loss: 0.511.. Validation accuracy: 0.871
# Epoch 3/10.. Train loss: 0.932.. Validation loss: 0.500.. Validation accuracy: 0.870
# Epoch 3/10.. Train loss: 0.882.. Validation loss: 0.504.. Validation accuracy: 0.874
# Epoch 3/10.. Train loss: 0.995.. Validation loss: 0.504.. Validation accuracy: 0.874
# Epoch 3/10.. Train loss: 0.897.. Validation loss: 0.504.. Validation accuracy: 0.864
# Epoch 3/10.. Train loss: 1.130.. Validation loss: 0.511.. Validation accuracy: 0.863
# Epoch 3/10.. Train loss: 1.108.. Validation loss: 0.505.. Validation accuracy: 0.867
# Epoch 3/10.. Train loss: 0.929.. Validation loss: 0.505.. Validation accuracy: 0.870
# Epoch 3/10.. Train loss: 1.029.. Validation loss: 0.515.. Validation accuracy: 0.865
# Epoch 3/10.. Train loss: 0.834.. Validation loss: 0.521.. Validation accuracy: 0.869
# Epoch 3/10.. Train loss: 1.009.. Validation loss: 0.523.. Validation accuracy: 0.867
# Epoch 3/10.. Train loss: 1.052.. Validation loss: 0.504.. Validation accuracy: 0.876
# Epoch 3/10.. Train loss: 0.868.. Validation loss: 0.500.. Validation accuracy: 0.872
# Epoch 3/10.. Train loss: 0.807.. Validation loss: 0.502.. Validation accuracy: 0.861
# Epoch 3/10.. Train loss: 1.101.. Validation loss: 0.496.. Validation accuracy: 0.868
# Epoch 3/10.. Train loss: 0.809.. Validation loss: 0.483.. Validation accuracy: 0.876
# Epoch 3/10.. Train loss: 0.892.. Validation loss: 0.489.. Validation accuracy: 0.875
# Epoch 3/10.. Train loss: 0.899.. Validation loss: 0.485.. Validation accuracy: 0.884
# Epoch 3/10.. Train loss: 0.794.. Validation loss: 0.488.. Validation accuracy: 0.877
# Epoch 3/10.. Train loss: 0.876.. Validation loss: 0.492.. Validation accuracy: 0.870
# Epoch 3/10.. Train loss: 0.886.. Validation loss: 0.497.. Validation accuracy: 0.870
# Epoch 4/10.. Train loss: 0.703.. Validation loss: 0.504.. Validation accuracy: 0.867
# Epoch 4/10.. Train loss: 0.690.. Validation loss: 0.507.. Validation accuracy: 0.865
# Epoch 4/10.. Train loss: 0.903.. Validation loss: 0.511.. Validation accuracy: 0.859
# Epoch 4/10.. Train loss: 0.725.. Validation loss: 0.517.. Validation accuracy: 0.855
# Epoch 4/10.. Train loss: 0.865.. Validation loss: 0.519.. Validation accuracy: 0.853
# Epoch 4/10.. Train loss: 0.837.. Validation loss: 0.497.. Validation accuracy: 0.866
# Epoch 4/10.. Train loss: 0.763.. Validation loss: 0.493.. Validation accuracy: 0.871
# Epoch 4/10.. Train loss: 0.907.. Validation loss: 0.494.. Validation accuracy: 0.870
# Epoch 4/10.. Train loss: 0.819.. Validation loss: 0.498.. Validation accuracy: 0.872
# Epoch 4/10.. Train loss: 0.899.. Validation loss: 0.495.. Validation accuracy: 0.869
# Epoch 4/10.. Train loss: 0.812.. Validation loss: 0.492.. Validation accuracy: 0.878
# Epoch 4/10.. Train loss: 0.854.. Validation loss: 0.472.. Validation accuracy: 0.880
# Epoch 4/10.. Train loss: 0.937.. Validation loss: 0.464.. Validation accuracy: 0.890
# Epoch 4/10.. Train loss: 0.725.. Validation loss: 0.461.. Validation accuracy: 0.885
# Epoch 4/10.. Train loss: 0.915.. Validation loss: 0.469.. Validation accuracy: 0.882
# Epoch 4/10.. Train loss: 0.803.. Validation loss: 0.484.. Validation accuracy: 0.885
# Epoch 4/10.. Train loss: 0.857.. Validation loss: 0.467.. Validation accuracy: 0.889
# Epoch 4/10.. Train loss: 0.916.. Validation loss: 0.461.. Validation accuracy: 0.892
# Epoch 4/10.. Train loss: 0.947.. Validation loss: 0.446.. Validation accuracy: 0.894
# Epoch 4/10.. Train loss: 0.608.. Validation loss: 0.449.. Validation accuracy: 0.890
# Epoch 4/10.. Train loss: 0.693.. Validation loss: 0.471.. Validation accuracy: 0.877
# Epoch 4/10.. Train loss: 0.617.. Validation loss: 0.489.. Validation accuracy: 0.877
# Epoch 4/10.. Train loss: 0.876.. Validation loss: 0.498.. Validation accuracy: 0.873
# Epoch 4/10.. Train loss: 0.729.. Validation loss: 0.484.. Validation accuracy: 0.872
# Epoch 4/10.. Train loss: 0.742.. Validation loss: 0.475.. Validation accuracy: 0.878
# Epoch 4/10.. Train loss: 0.642.. Validation loss: 0.457.. Validation accuracy: 0.882
# Epoch 4/10.. Train loss: 0.921.. Validation loss: 0.448.. Validation accuracy: 0.893
# Epoch 4/10.. Train loss: 0.796.. Validation loss: 0.435.. Validation accuracy: 0.895
# Epoch 4/10.. Train loss: 0.639.. Validation loss: 0.424.. Validation accuracy: 0.890
# Epoch 4/10.. Train loss: 0.864.. Validation loss: 0.431.. Validation accuracy: 0.883
# Epoch 4/10.. Train loss: 0.924.. Validation loss: 0.441.. Validation accuracy: 0.882
# Epoch 4/10.. Train loss: 0.487.. Validation loss: 0.450.. Validation accuracy: 0.883
# Epoch 4/10.. Train loss: 1.071.. Validation loss: 0.448.. Validation accuracy: 0.882
# Epoch 4/10.. Train loss: 0.948.. Validation loss: 0.444.. Validation accuracy: 0.888
# Epoch 4/10.. Train loss: 0.826.. Validation loss: 0.435.. Validation accuracy: 0.888
# Epoch 4/10.. Train loss: 0.833.. Validation loss: 0.443.. Validation accuracy: 0.889
# Epoch 4/10.. Train loss: 0.849.. Validation loss: 0.454.. Validation accuracy: 0.886
# Epoch 4/10.. Train loss: 0.759.. Validation loss: 0.473.. Validation accuracy: 0.875
# Epoch 4/10.. Train loss: 0.699.. Validation loss: 0.475.. Validation accuracy: 0.865
# Epoch 4/10.. Train loss: 0.989.. Validation loss: 0.463.. Validation accuracy: 0.875
# Epoch 4/10.. Train loss: 0.765.. Validation loss: 0.441.. Validation accuracy: 0.885
# Epoch 4/10.. Train loss: 0.838.. Validation loss: 0.421.. Validation accuracy: 0.894
# Epoch 4/10.. Train loss: 0.780.. Validation loss: 0.407.. Validation accuracy: 0.895
# Epoch 4/10.. Train loss: 0.792.. Validation loss: 0.412.. Validation accuracy: 0.892
# Epoch 4/10.. Train loss: 0.782.. Validation loss: 0.416.. Validation accuracy: 0.892
# Epoch 4/10.. Train loss: 0.865.. Validation loss: 0.424.. Validation accuracy: 0.891
# Epoch 4/10.. Train loss: 0.860.. Validation loss: 0.428.. Validation accuracy: 0.891
# Epoch 4/10.. Train loss: 0.807.. Validation loss: 0.428.. Validation accuracy: 0.887
# Epoch 4/10.. Train loss: 0.808.. Validation loss: 0.426.. Validation accuracy: 0.890
# Epoch 4/10.. Train loss: 0.769.. Validation loss: 0.415.. Validation accuracy: 0.889
# Epoch 4/10.. Train loss: 0.789.. Validation loss: 0.411.. Validation accuracy: 0.896
# Epoch 4/10.. Train loss: 0.785.. Validation loss: 0.400.. Validation accuracy: 0.896
# Epoch 5/10.. Train loss: 0.668.. Validation loss: 0.398.. Validation accuracy: 0.899
# Epoch 5/10.. Train loss: 0.672.. Validation loss: 0.407.. Validation accuracy: 0.896
# Epoch 5/10.. Train loss: 0.712.. Validation loss: 0.412.. Validation accuracy: 0.893
# Epoch 5/10.. Train loss: 0.666.. Validation loss: 0.409.. Validation accuracy: 0.893
# Epoch 5/10.. Train loss: 0.590.. Validation loss: 0.395.. Validation accuracy: 0.900
# Epoch 5/10.. Train loss: 0.802.. Validation loss: 0.383.. Validation accuracy: 0.901
# Epoch 5/10.. Train loss: 0.780.. Validation loss: 0.372.. Validation accuracy: 0.899
# Epoch 5/10.. Train loss: 0.826.. Validation loss: 0.364.. Validation accuracy: 0.904
# Epoch 5/10.. Train loss: 0.819.. Validation loss: 0.367.. Validation accuracy: 0.899
# Epoch 5/10.. Train loss: 0.716.. Validation loss: 0.373.. Validation accuracy: 0.894
# Epoch 5/10.. Train loss: 0.745.. Validation loss: 0.372.. Validation accuracy: 0.900
# Epoch 5/10.. Train loss: 0.656.. Validation loss: 0.380.. Validation accuracy: 0.896
# Epoch 5/10.. Train loss: 0.807.. Validation loss: 0.388.. Validation accuracy: 0.895
# Epoch 5/10.. Train loss: 0.890.. Validation loss: 0.397.. Validation accuracy: 0.895
# Epoch 5/10.. Train loss: 0.832.. Validation loss: 0.401.. Validation accuracy: 0.899
# Epoch 5/10.. Train loss: 0.639.. Validation loss: 0.401.. Validation accuracy: 0.906
# Epoch 5/10.. Train loss: 0.739.. Validation loss: 0.396.. Validation accuracy: 0.908
# Epoch 5/10.. Train loss: 0.851.. Validation loss: 0.406.. Validation accuracy: 0.897
# Epoch 5/10.. Train loss: 0.808.. Validation loss: 0.410.. Validation accuracy: 0.899
# Epoch 5/10.. Train loss: 0.762.. Validation loss: 0.413.. Validation accuracy: 0.901
# Epoch 5/10.. Train loss: 0.843.. Validation loss: 0.407.. Validation accuracy: 0.895
# Epoch 5/10.. Train loss: 0.890.. Validation loss: 0.404.. Validation accuracy: 0.901
# Epoch 5/10.. Train loss: 0.813.. Validation loss: 0.410.. Validation accuracy: 0.906
# Epoch 5/10.. Train loss: 0.734.. Validation loss: 0.399.. Validation accuracy: 0.903
# Epoch 5/10.. Train loss: 0.667.. Validation loss: 0.398.. Validation accuracy: 0.900
# Epoch 5/10.. Train loss: 0.744.. Validation loss: 0.395.. Validation accuracy: 0.906
# Epoch 5/10.. Train loss: 0.653.. Validation loss: 0.406.. Validation accuracy: 0.903
# Epoch 5/10.. Train loss: 0.754.. Validation loss: 0.414.. Validation accuracy: 0.897
# Epoch 5/10.. Train loss: 0.675.. Validation loss: 0.411.. Validation accuracy: 0.898
# Epoch 5/10.. Train loss: 0.553.. Validation loss: 0.408.. Validation accuracy: 0.898
# Epoch 5/10.. Train loss: 0.595.. Validation loss: 0.397.. Validation accuracy: 0.896
# Epoch 5/10.. Train loss: 0.806.. Validation loss: 0.394.. Validation accuracy: 0.896
# Epoch 5/10.. Train loss: 0.854.. Validation loss: 0.384.. Validation accuracy: 0.905
# Epoch 5/10.. Train loss: 0.600.. Validation loss: 0.384.. Validation accuracy: 0.900
# Epoch 5/10.. Train loss: 0.713.. Validation loss: 0.374.. Validation accuracy: 0.899
# Epoch 5/10.. Train loss: 0.832.. Validation loss: 0.370.. Validation accuracy: 0.903
# Epoch 5/10.. Train loss: 0.645.. Validation loss: 0.374.. Validation accuracy: 0.906
# Epoch 5/10.. Train loss: 0.634.. Validation loss: 0.374.. Validation accuracy: 0.907
# Epoch 5/10.. Train loss: 0.836.. Validation loss: 0.385.. Validation accuracy: 0.902
# Epoch 5/10.. Train loss: 0.743.. Validation loss: 0.382.. Validation accuracy: 0.903
# Epoch 5/10.. Train loss: 0.689.. Validation loss: 0.379.. Validation accuracy: 0.901
# Epoch 5/10.. Train loss: 0.728.. Validation loss: 0.382.. Validation accuracy: 0.895
# Epoch 5/10.. Train loss: 0.733.. Validation loss: 0.374.. Validation accuracy: 0.898
# Epoch 5/10.. Train loss: 0.771.. Validation loss: 0.375.. Validation accuracy: 0.897
# Epoch 5/10.. Train loss: 0.909.. Validation loss: 0.375.. Validation accuracy: 0.895
# Epoch 5/10.. Train loss: 0.831.. Validation loss: 0.378.. Validation accuracy: 0.894
# Epoch 5/10.. Train loss: 0.794.. Validation loss: 0.376.. Validation accuracy: 0.893
# Epoch 5/10.. Train loss: 0.718.. Validation loss: 0.374.. Validation accuracy: 0.890
# Epoch 5/10.. Train loss: 0.582.. Validation loss: 0.385.. Validation accuracy: 0.894
# Epoch 5/10.. Train loss: 0.693.. Validation loss: 0.396.. Validation accuracy: 0.887
# Epoch 5/10.. Train loss: 0.709.. Validation loss: 0.393.. Validation accuracy: 0.891
# Epoch 6/10.. Train loss: 0.672.. Validation loss: 0.384.. Validation accuracy: 0.893
# Epoch 6/10.. Train loss: 0.792.. Validation loss: 0.371.. Validation accuracy: 0.896
# Epoch 6/10.. Train loss: 0.757.. Validation loss: 0.364.. Validation accuracy: 0.903
# Epoch 6/10.. Train loss: 0.774.. Validation loss: 0.351.. Validation accuracy: 0.915
# Epoch 6/10.. Train loss: 0.591.. Validation loss: 0.346.. Validation accuracy: 0.911
# Epoch 6/10.. Train loss: 0.736.. Validation loss: 0.352.. Validation accuracy: 0.903
# Epoch 6/10.. Train loss: 0.509.. Validation loss: 0.357.. Validation accuracy: 0.904
# Epoch 6/10.. Train loss: 0.542.. Validation loss: 0.366.. Validation accuracy: 0.904
# Epoch 6/10.. Train loss: 0.672.. Validation loss: 0.350.. Validation accuracy: 0.901
# Epoch 6/10.. Train loss: 0.828.. Validation loss: 0.333.. Validation accuracy: 0.915
# Epoch 6/10.. Train loss: 0.549.. Validation loss: 0.318.. Validation accuracy: 0.916
# Epoch 6/10.. Train loss: 0.618.. Validation loss: 0.318.. Validation accuracy: 0.919
# Epoch 6/10.. Train loss: 0.788.. Validation loss: 0.318.. Validation accuracy: 0.921
# Epoch 6/10.. Train loss: 0.728.. Validation loss: 0.325.. Validation accuracy: 0.914
# Epoch 6/10.. Train loss: 0.531.. Validation loss: 0.329.. Validation accuracy: 0.912
# Epoch 6/10.. Train loss: 0.560.. Validation loss: 0.329.. Validation accuracy: 0.914
# Epoch 6/10.. Train loss: 0.516.. Validation loss: 0.337.. Validation accuracy: 0.911
# Epoch 6/10.. Train loss: 0.843.. Validation loss: 0.345.. Validation accuracy: 0.906
# Epoch 6/10.. Train loss: 0.525.. Validation loss: 0.357.. Validation accuracy: 0.906
# Epoch 6/10.. Train loss: 0.664.. Validation loss: 0.356.. Validation accuracy: 0.904
# Epoch 6/10.. Train loss: 0.730.. Validation loss: 0.351.. Validation accuracy: 0.911
# Epoch 6/10.. Train loss: 0.540.. Validation loss: 0.355.. Validation accuracy: 0.911
# Epoch 6/10.. Train loss: 0.626.. Validation loss: 0.354.. Validation accuracy: 0.912
# Epoch 6/10.. Train loss: 0.647.. Validation loss: 0.367.. Validation accuracy: 0.906
# Epoch 6/10.. Train loss: 0.663.. Validation loss: 0.371.. Validation accuracy: 0.900
# Epoch 6/10.. Train loss: 0.641.. Validation loss: 0.370.. Validation accuracy: 0.896
# Epoch 6/10.. Train loss: 0.790.. Validation loss: 0.356.. Validation accuracy: 0.895
# Epoch 6/10.. Train loss: 0.485.. Validation loss: 0.342.. Validation accuracy: 0.904
# Epoch 6/10.. Train loss: 0.647.. Validation loss: 0.335.. Validation accuracy: 0.909
# Epoch 6/10.. Train loss: 0.579.. Validation loss: 0.332.. Validation accuracy: 0.909
# Epoch 6/10.. Train loss: 0.778.. Validation loss: 0.330.. Validation accuracy: 0.911
# Epoch 6/10.. Train loss: 0.645.. Validation loss: 0.332.. Validation accuracy: 0.910
# Epoch 6/10.. Train loss: 0.486.. Validation loss: 0.338.. Validation accuracy: 0.910
# Epoch 6/10.. Train loss: 0.756.. Validation loss: 0.342.. Validation accuracy: 0.906
# Epoch 6/10.. Train loss: 0.772.. Validation loss: 0.343.. Validation accuracy: 0.904
# Epoch 6/10.. Train loss: 0.799.. Validation loss: 0.342.. Validation accuracy: 0.907
# Epoch 6/10.. Train loss: 0.542.. Validation loss: 0.342.. Validation accuracy: 0.909
# Epoch 6/10.. Train loss: 0.693.. Validation loss: 0.341.. Validation accuracy: 0.902
# Epoch 6/10.. Train loss: 0.500.. Validation loss: 0.346.. Validation accuracy: 0.905
# Epoch 6/10.. Train loss: 0.566.. Validation loss: 0.350.. Validation accuracy: 0.899
# Epoch 6/10.. Train loss: 0.579.. Validation loss: 0.337.. Validation accuracy: 0.903
# Epoch 6/10.. Train loss: 0.619.. Validation loss: 0.330.. Validation accuracy: 0.909
# Epoch 6/10.. Train loss: 0.651.. Validation loss: 0.325.. Validation accuracy: 0.909
# Epoch 6/10.. Train loss: 0.863.. Validation loss: 0.326.. Validation accuracy: 0.908
# Epoch 6/10.. Train loss: 0.665.. Validation loss: 0.317.. Validation accuracy: 0.910
# Epoch 6/10.. Train loss: 0.607.. Validation loss: 0.327.. Validation accuracy: 0.908
# Epoch 6/10.. Train loss: 0.958.. Validation loss: 0.328.. Validation accuracy: 0.904
# Epoch 6/10.. Train loss: 0.416.. Validation loss: 0.328.. Validation accuracy: 0.906
# Epoch 6/10.. Train loss: 0.504.. Validation loss: 0.332.. Validation accuracy: 0.910
# Epoch 6/10.. Train loss: 0.614.. Validation loss: 0.345.. Validation accuracy: 0.910
# Epoch 6/10.. Train loss: 0.691.. Validation loss: 0.346.. Validation accuracy: 0.912
# Epoch 6/10.. Train loss: 0.452.. Validation loss: 0.354.. Validation accuracy: 0.907
# Epoch 7/10.. Train loss: 0.601.. Validation loss: 0.342.. Validation accuracy: 0.912
# Epoch 7/10.. Train loss: 0.521.. Validation loss: 0.328.. Validation accuracy: 0.912
# Epoch 7/10.. Train loss: 0.629.. Validation loss: 0.318.. Validation accuracy: 0.918
# Epoch 7/10.. Train loss: 0.766.. Validation loss: 0.315.. Validation accuracy: 0.915
# Epoch 7/10.. Train loss: 0.500.. Validation loss: 0.321.. Validation accuracy: 0.911
# Epoch 7/10.. Train loss: 0.656.. Validation loss: 0.328.. Validation accuracy: 0.913
# Epoch 7/10.. Train loss: 0.393.. Validation loss: 0.342.. Validation accuracy: 0.915
# Epoch 7/10.. Train loss: 0.838.. Validation loss: 0.350.. Validation accuracy: 0.916
# Epoch 7/10.. Train loss: 0.551.. Validation loss: 0.348.. Validation accuracy: 0.914
# Epoch 7/10.. Train loss: 0.499.. Validation loss: 0.345.. Validation accuracy: 0.913
# Epoch 7/10.. Train loss: 0.670.. Validation loss: 0.333.. Validation accuracy: 0.911
# Epoch 7/10.. Train loss: 0.587.. Validation loss: 0.329.. Validation accuracy: 0.909
# Epoch 7/10.. Train loss: 0.517.. Validation loss: 0.329.. Validation accuracy: 0.907
# Epoch 7/10.. Train loss: 0.852.. Validation loss: 0.325.. Validation accuracy: 0.909
# Epoch 7/10.. Train loss: 0.619.. Validation loss: 0.334.. Validation accuracy: 0.903
# Epoch 7/10.. Train loss: 0.433.. Validation loss: 0.343.. Validation accuracy: 0.909
# Epoch 7/10.. Train loss: 0.650.. Validation loss: 0.350.. Validation accuracy: 0.908
# Epoch 7/10.. Train loss: 0.729.. Validation loss: 0.347.. Validation accuracy: 0.908
# Epoch 7/10.. Train loss: 0.468.. Validation loss: 0.357.. Validation accuracy: 0.903
# Epoch 7/10.. Train loss: 0.729.. Validation loss: 0.339.. Validation accuracy: 0.915
# Epoch 7/10.. Train loss: 0.618.. Validation loss: 0.336.. Validation accuracy: 0.915
# Epoch 7/10.. Train loss: 0.656.. Validation loss: 0.325.. Validation accuracy: 0.921
# Epoch 7/10.. Train loss: 0.557.. Validation loss: 0.325.. Validation accuracy: 0.919
# Epoch 7/10.. Train loss: 0.444.. Validation loss: 0.318.. Validation accuracy: 0.916
# Epoch 7/10.. Train loss: 0.367.. Validation loss: 0.322.. Validation accuracy: 0.917
# Epoch 7/10.. Train loss: 0.594.. Validation loss: 0.333.. Validation accuracy: 0.918
# Epoch 7/10.. Train loss: 0.402.. Validation loss: 0.340.. Validation accuracy: 0.915
# Epoch 7/10.. Train loss: 0.550.. Validation loss: 0.338.. Validation accuracy: 0.915
# Epoch 7/10.. Train loss: 0.660.. Validation loss: 0.352.. Validation accuracy: 0.908
# Epoch 7/10.. Train loss: 0.595.. Validation loss: 0.343.. Validation accuracy: 0.912
# Epoch 7/10.. Train loss: 0.610.. Validation loss: 0.347.. Validation accuracy: 0.908
# Epoch 7/10.. Train loss: 0.657.. Validation loss: 0.340.. Validation accuracy: 0.917
# Epoch 7/10.. Train loss: 0.465.. Validation loss: 0.336.. Validation accuracy: 0.919
# Epoch 7/10.. Train loss: 0.647.. Validation loss: 0.339.. Validation accuracy: 0.918
# Epoch 7/10.. Train loss: 0.629.. Validation loss: 0.333.. Validation accuracy: 0.922
# Epoch 7/10.. Train loss: 0.677.. Validation loss: 0.326.. Validation accuracy: 0.920
# Epoch 7/10.. Train loss: 0.778.. Validation loss: 0.321.. Validation accuracy: 0.923
# Epoch 7/10.. Train loss: 0.837.. Validation loss: 0.314.. Validation accuracy: 0.924
# Epoch 7/10.. Train loss: 0.655.. Validation loss: 0.318.. Validation accuracy: 0.917
# Epoch 7/10.. Train loss: 0.564.. Validation loss: 0.321.. Validation accuracy: 0.912
# Epoch 7/10.. Train loss: 0.707.. Validation loss: 0.330.. Validation accuracy: 0.909
# Epoch 7/10.. Train loss: 0.625.. Validation loss: 0.327.. Validation accuracy: 0.913
# Epoch 7/10.. Train loss: 0.810.. Validation loss: 0.330.. Validation accuracy: 0.915
# Epoch 7/10.. Train loss: 0.469.. Validation loss: 0.331.. Validation accuracy: 0.917
# Epoch 7/10.. Train loss: 0.689.. Validation loss: 0.334.. Validation accuracy: 0.915
# Epoch 7/10.. Train loss: 0.541.. Validation loss: 0.333.. Validation accuracy: 0.914
# Epoch 7/10.. Train loss: 0.609.. Validation loss: 0.334.. Validation accuracy: 0.914
# Epoch 7/10.. Train loss: 0.571.. Validation loss: 0.340.. Validation accuracy: 0.917
# Epoch 7/10.. Train loss: 0.569.. Validation loss: 0.339.. Validation accuracy: 0.917
# Epoch 7/10.. Train loss: 0.478.. Validation loss: 0.348.. Validation accuracy: 0.913
# Epoch 7/10.. Train loss: 0.610.. Validation loss: 0.354.. Validation accuracy: 0.914
# Epoch 8/10.. Train loss: 0.580.. Validation loss: 0.358.. Validation accuracy: 0.906
# Epoch 8/10.. Train loss: 0.642.. Validation loss: 0.354.. Validation accuracy: 0.905
# Epoch 8/10.. Train loss: 0.651.. Validation loss: 0.357.. Validation accuracy: 0.908
# Epoch 8/10.. Train loss: 0.588.. Validation loss: 0.358.. Validation accuracy: 0.909
# Epoch 8/10.. Train loss: 0.590.. Validation loss: 0.356.. Validation accuracy: 0.906
# Epoch 8/10.. Train loss: 0.755.. Validation loss: 0.345.. Validation accuracy: 0.908
# Epoch 8/10.. Train loss: 0.500.. Validation loss: 0.337.. Validation accuracy: 0.910
# Epoch 8/10.. Train loss: 0.727.. Validation loss: 0.325.. Validation accuracy: 0.914
# Epoch 8/10.. Train loss: 0.710.. Validation loss: 0.324.. Validation accuracy: 0.907
# Epoch 8/10.. Train loss: 0.546.. Validation loss: 0.317.. Validation accuracy: 0.914
# Epoch 8/10.. Train loss: 0.704.. Validation loss: 0.318.. Validation accuracy: 0.912
# Epoch 8/10.. Train loss: 0.564.. Validation loss: 0.324.. Validation accuracy: 0.909
# Epoch 8/10.. Train loss: 0.496.. Validation loss: 0.324.. Validation accuracy: 0.914
# Epoch 8/10.. Train loss: 0.451.. Validation loss: 0.336.. Validation accuracy: 0.911
# Epoch 8/10.. Train loss: 0.538.. Validation loss: 0.334.. Validation accuracy: 0.911
# Epoch 8/10.. Train loss: 0.789.. Validation loss: 0.335.. Validation accuracy: 0.918
# Epoch 8/10.. Train loss: 0.503.. Validation loss: 0.327.. Validation accuracy: 0.916
# Epoch 8/10.. Train loss: 0.504.. Validation loss: 0.330.. Validation accuracy: 0.911
# Epoch 8/10.. Train loss: 0.520.. Validation loss: 0.324.. Validation accuracy: 0.913
# Epoch 8/10.. Train loss: 0.624.. Validation loss: 0.320.. Validation accuracy: 0.912
# Epoch 8/10.. Train loss: 0.559.. Validation loss: 0.322.. Validation accuracy: 0.914
# Epoch 8/10.. Train loss: 0.552.. Validation loss: 0.322.. Validation accuracy: 0.915
# Epoch 8/10.. Train loss: 0.458.. Validation loss: 0.312.. Validation accuracy: 0.917
# Epoch 8/10.. Train loss: 0.577.. Validation loss: 0.302.. Validation accuracy: 0.926
# Epoch 8/10.. Train loss: 0.521.. Validation loss: 0.302.. Validation accuracy: 0.925
# Epoch 8/10.. Train loss: 0.435.. Validation loss: 0.310.. Validation accuracy: 0.921
# Epoch 8/10.. Train loss: 0.799.. Validation loss: 0.316.. Validation accuracy: 0.920
# Epoch 8/10.. Train loss: 0.609.. Validation loss: 0.321.. Validation accuracy: 0.916
# Epoch 8/10.. Train loss: 0.589.. Validation loss: 0.329.. Validation accuracy: 0.908
# Epoch 8/10.. Train loss: 0.784.. Validation loss: 0.336.. Validation accuracy: 0.907
# Epoch 8/10.. Train loss: 0.538.. Validation loss: 0.334.. Validation accuracy: 0.912
# Epoch 8/10.. Train loss: 0.680.. Validation loss: 0.333.. Validation accuracy: 0.910
# Epoch 8/10.. Train loss: 0.664.. Validation loss: 0.328.. Validation accuracy: 0.919
# Epoch 8/10.. Train loss: 0.639.. Validation loss: 0.329.. Validation accuracy: 0.915
# Epoch 8/10.. Train loss: 0.502.. Validation loss: 0.324.. Validation accuracy: 0.913
# Epoch 8/10.. Train loss: 0.629.. Validation loss: 0.317.. Validation accuracy: 0.917
# Epoch 8/10.. Train loss: 0.695.. Validation loss: 0.306.. Validation accuracy: 0.916
# Epoch 8/10.. Train loss: 0.550.. Validation loss: 0.303.. Validation accuracy: 0.920
# Epoch 8/10.. Train loss: 0.444.. Validation loss: 0.304.. Validation accuracy: 0.921
# Epoch 8/10.. Train loss: 0.590.. Validation loss: 0.306.. Validation accuracy: 0.923
# Epoch 8/10.. Train loss: 0.565.. Validation loss: 0.308.. Validation accuracy: 0.924
# Epoch 8/10.. Train loss: 0.679.. Validation loss: 0.306.. Validation accuracy: 0.926
# Epoch 8/10.. Train loss: 0.473.. Validation loss: 0.297.. Validation accuracy: 0.930
# Epoch 8/10.. Train loss: 0.508.. Validation loss: 0.296.. Validation accuracy: 0.929
# Epoch 8/10.. Train loss: 0.565.. Validation loss: 0.295.. Validation accuracy: 0.932
# Epoch 8/10.. Train loss: 0.583.. Validation loss: 0.284.. Validation accuracy: 0.929
# Epoch 8/10.. Train loss: 0.537.. Validation loss: 0.287.. Validation accuracy: 0.925
# Epoch 8/10.. Train loss: 0.476.. Validation loss: 0.292.. Validation accuracy: 0.924
# Epoch 8/10.. Train loss: 0.542.. Validation loss: 0.291.. Validation accuracy: 0.922
# Epoch 8/10.. Train loss: 0.672.. Validation loss: 0.286.. Validation accuracy: 0.924
# Epoch 8/10.. Train loss: 0.569.. Validation loss: 0.282.. Validation accuracy: 0.927
# Epoch 8/10.. Train loss: 0.549.. Validation loss: 0.279.. Validation accuracy: 0.925
# Epoch 9/10.. Train loss: 0.724.. Validation loss: 0.275.. Validation accuracy: 0.926
# Epoch 9/10.. Train loss: 0.711.. Validation loss: 0.276.. Validation accuracy: 0.926
# Epoch 9/10.. Train loss: 0.471.. Validation loss: 0.274.. Validation accuracy: 0.928
# Epoch 9/10.. Train loss: 0.785.. Validation loss: 0.284.. Validation accuracy: 0.923
# Epoch 9/10.. Train loss: 0.447.. Validation loss: 0.288.. Validation accuracy: 0.914
# Epoch 9/10.. Train loss: 0.614.. Validation loss: 0.288.. Validation accuracy: 0.921
# Epoch 9/10.. Train loss: 0.622.. Validation loss: 0.292.. Validation accuracy: 0.924
# Epoch 9/10.. Train loss: 0.466.. Validation loss: 0.298.. Validation accuracy: 0.922
# Epoch 9/10.. Train loss: 0.464.. Validation loss: 0.303.. Validation accuracy: 0.919
# Epoch 9/10.. Train loss: 0.740.. Validation loss: 0.305.. Validation accuracy: 0.923
# Epoch 9/10.. Train loss: 0.461.. Validation loss: 0.314.. Validation accuracy: 0.922
# Epoch 9/10.. Train loss: 0.511.. Validation loss: 0.316.. Validation accuracy: 0.912
# Epoch 9/10.. Train loss: 0.469.. Validation loss: 0.313.. Validation accuracy: 0.913
# Epoch 9/10.. Train loss: 0.675.. Validation loss: 0.300.. Validation accuracy: 0.921
# Epoch 9/10.. Train loss: 0.500.. Validation loss: 0.295.. Validation accuracy: 0.920
# Epoch 9/10.. Train loss: 0.394.. Validation loss: 0.290.. Validation accuracy: 0.921
# Epoch 9/10.. Train loss: 0.519.. Validation loss: 0.286.. Validation accuracy: 0.923
# Epoch 9/10.. Train loss: 0.464.. Validation loss: 0.274.. Validation accuracy: 0.928
# Epoch 9/10.. Train loss: 0.450.. Validation loss: 0.274.. Validation accuracy: 0.929
# Epoch 9/10.. Train loss: 0.550.. Validation loss: 0.272.. Validation accuracy: 0.936
# Epoch 9/10.. Train loss: 0.652.. Validation loss: 0.272.. Validation accuracy: 0.930
# Epoch 9/10.. Train loss: 0.524.. Validation loss: 0.270.. Validation accuracy: 0.935
# Epoch 9/10.. Train loss: 0.628.. Validation loss: 0.263.. Validation accuracy: 0.930
# Epoch 9/10.. Train loss: 0.571.. Validation loss: 0.262.. Validation accuracy: 0.935
# Epoch 9/10.. Train loss: 0.545.. Validation loss: 0.261.. Validation accuracy: 0.932
# Epoch 9/10.. Train loss: 0.678.. Validation loss: 0.264.. Validation accuracy: 0.932
# Epoch 9/10.. Train loss: 0.751.. Validation loss: 0.267.. Validation accuracy: 0.931
# Epoch 9/10.. Train loss: 0.633.. Validation loss: 0.271.. Validation accuracy: 0.931
# Epoch 9/10.. Train loss: 0.619.. Validation loss: 0.276.. Validation accuracy: 0.933
# Epoch 9/10.. Train loss: 0.424.. Validation loss: 0.279.. Validation accuracy: 0.927
# Epoch 9/10.. Train loss: 0.370.. Validation loss: 0.284.. Validation accuracy: 0.924
# Epoch 9/10.. Train loss: 0.451.. Validation loss: 0.282.. Validation accuracy: 0.918
# Epoch 9/10.. Train loss: 0.374.. Validation loss: 0.287.. Validation accuracy: 0.913
# Epoch 9/10.. Train loss: 0.465.. Validation loss: 0.293.. Validation accuracy: 0.915
# Epoch 9/10.. Train loss: 0.383.. Validation loss: 0.298.. Validation accuracy: 0.916
# Epoch 9/10.. Train loss: 0.587.. Validation loss: 0.303.. Validation accuracy: 0.919
# Epoch 9/10.. Train loss: 0.647.. Validation loss: 0.298.. Validation accuracy: 0.922
# Epoch 9/10.. Train loss: 0.449.. Validation loss: 0.294.. Validation accuracy: 0.920
# Epoch 9/10.. Train loss: 0.400.. Validation loss: 0.295.. Validation accuracy: 0.923
# Epoch 9/10.. Train loss: 0.474.. Validation loss: 0.290.. Validation accuracy: 0.924
# Epoch 9/10.. Train loss: 0.568.. Validation loss: 0.294.. Validation accuracy: 0.919
# Epoch 9/10.. Train loss: 0.353.. Validation loss: 0.300.. Validation accuracy: 0.920
# Epoch 9/10.. Train loss: 0.578.. Validation loss: 0.306.. Validation accuracy: 0.920
# Epoch 9/10.. Train loss: 0.492.. Validation loss: 0.301.. Validation accuracy: 0.925
# Epoch 9/10.. Train loss: 0.674.. Validation loss: 0.293.. Validation accuracy: 0.922
# Epoch 9/10.. Train loss: 0.539.. Validation loss: 0.291.. Validation accuracy: 0.922
# Epoch 9/10.. Train loss: 0.738.. Validation loss: 0.290.. Validation accuracy: 0.928
# Epoch 9/10.. Train loss: 0.611.. Validation loss: 0.293.. Validation accuracy: 0.926
# Epoch 9/10.. Train loss: 0.569.. Validation loss: 0.304.. Validation accuracy: 0.921
# Epoch 9/10.. Train loss: 0.517.. Validation loss: 0.315.. Validation accuracy: 0.914
# Epoch 9/10.. Train loss: 0.685.. Validation loss: 0.317.. Validation accuracy: 0.906
# Epoch 10/10.. Train loss: 0.482.. Validation loss: 0.314.. Validation accuracy: 0.907
# Epoch 10/10.. Train loss: 0.533.. Validation loss: 0.306.. Validation accuracy: 0.916
# Epoch 10/10.. Train loss: 0.512.. Validation loss: 0.301.. Validation accuracy: 0.920
# Epoch 10/10.. Train loss: 0.583.. Validation loss: 0.297.. Validation accuracy: 0.921
# Epoch 10/10.. Train loss: 0.559.. Validation loss: 0.295.. Validation accuracy: 0.921
# Epoch 10/10.. Train loss: 0.596.. Validation loss: 0.293.. Validation accuracy: 0.930
# Epoch 10/10.. Train loss: 0.523.. Validation loss: 0.285.. Validation accuracy: 0.936
# Epoch 10/10.. Train loss: 0.447.. Validation loss: 0.277.. Validation accuracy: 0.938
# Epoch 10/10.. Train loss: 0.519.. Validation loss: 0.275.. Validation accuracy: 0.936
# Epoch 10/10.. Train loss: 0.559.. Validation loss: 0.275.. Validation accuracy: 0.934
# Epoch 10/10.. Train loss: 0.527.. Validation loss: 0.284.. Validation accuracy: 0.930
# Epoch 10/10.. Train loss: 0.566.. Validation loss: 0.297.. Validation accuracy: 0.927
# Epoch 10/10.. Train loss: 0.338.. Validation loss: 0.300.. Validation accuracy: 0.922
# Epoch 10/10.. Train loss: 0.683.. Validation loss: 0.300.. Validation accuracy: 0.921
# Epoch 10/10.. Train loss: 0.726.. Validation loss: 0.301.. Validation accuracy: 0.920
# Epoch 10/10.. Train loss: 0.513.. Validation loss: 0.301.. Validation accuracy: 0.921
# Epoch 10/10.. Train loss: 0.601.. Validation loss: 0.303.. Validation accuracy: 0.918
# Epoch 10/10.. Train loss: 0.488.. Validation loss: 0.304.. Validation accuracy: 0.918
# Epoch 10/10.. Train loss: 0.409.. Validation loss: 0.310.. Validation accuracy: 0.915
# Epoch 10/10.. Train loss: 0.461.. Validation loss: 0.308.. Validation accuracy: 0.915
# Epoch 10/10.. Train loss: 0.534.. Validation loss: 0.307.. Validation accuracy: 0.913
# Epoch 10/10.. Train loss: 0.476.. Validation loss: 0.302.. Validation accuracy: 0.918
# Epoch 10/10.. Train loss: 0.777.. Validation loss: 0.299.. Validation accuracy: 0.918
# Epoch 10/10.. Train loss: 0.334.. Validation loss: 0.293.. Validation accuracy: 0.922
# Epoch 10/10.. Train loss: 0.744.. Validation loss: 0.289.. Validation accuracy: 0.925
# Epoch 10/10.. Train loss: 0.713.. Validation loss: 0.283.. Validation accuracy: 0.928
# Epoch 10/10.. Train loss: 0.613.. Validation loss: 0.282.. Validation accuracy: 0.932
# Epoch 10/10.. Train loss: 0.480.. Validation loss: 0.281.. Validation accuracy: 0.934
# Epoch 10/10.. Train loss: 0.352.. Validation loss: 0.290.. Validation accuracy: 0.932
# Epoch 10/10.. Train loss: 0.463.. Validation loss: 0.285.. Validation accuracy: 0.933
# Epoch 10/10.. Train loss: 0.554.. Validation loss: 0.300.. Validation accuracy: 0.925
# Epoch 10/10.. Train loss: 0.481.. Validation loss: 0.299.. Validation accuracy: 0.923
# Epoch 10/10.. Train loss: 0.480.. Validation loss: 0.282.. Validation accuracy: 0.926
# Epoch 10/10.. Train loss: 0.459.. Validation loss: 0.282.. Validation accuracy: 0.925
# Epoch 10/10.. Train loss: 0.674.. Validation loss: 0.272.. Validation accuracy: 0.927
# Epoch 10/10.. Train loss: 0.536.. Validation loss: 0.268.. Validation accuracy: 0.921
# Epoch 10/10.. Train loss: 0.480.. Validation loss: 0.273.. Validation accuracy: 0.918
# Epoch 10/10.. Train loss: 0.654.. Validation loss: 0.278.. Validation accuracy: 0.917
# Epoch 10/10.. Train loss: 0.704.. Validation loss: 0.293.. Validation accuracy: 0.919
# Epoch 10/10.. Train loss: 0.529.. Validation loss: 0.304.. Validation accuracy: 0.918
# Epoch 10/10.. Train loss: 0.571.. Validation loss: 0.314.. Validation accuracy: 0.914
# Epoch 10/10.. Train loss: 0.501.. Validation loss: 0.319.. Validation accuracy: 0.908
# Epoch 10/10.. Train loss: 0.526.. Validation loss: 0.316.. Validation accuracy: 0.907
# Epoch 10/10.. Train loss: 0.541.. Validation loss: 0.314.. Validation accuracy: 0.909
# Epoch 10/10.. Train loss: 0.608.. Validation loss: 0.316.. Validation accuracy: 0.909
# Epoch 10/10.. Train loss: 0.510.. Validation loss: 0.299.. Validation accuracy: 0.910
# Epoch 10/10.. Train loss: 0.569.. Validation loss: 0.283.. Validation accuracy: 0.918
# Epoch 10/10.. Train loss: 0.439.. Validation loss: 0.281.. Validation accuracy: 0.924
# Epoch 10/10.. Train loss: 0.616.. Validation loss: 0.277.. Validation accuracy: 0.921
# Epoch 10/10.. Train loss: 0.649.. Validation loss: 0.272.. Validation accuracy: 0.923
# Epoch 10/10.. Train loss: 0.411.. Validation loss: 0.264.. Validation accuracy: 0.923
# Epoch 10/10.. Train loss: 0.508.. Validation loss: 0.261.. Validation accuracy: 0.929
# Total running time is 1926

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
# TODO: Do validation on the test set
test_loss = 0
test_accuracy = 0
with torch.no_grad():
    # run the test
    for images, labels in testloader:
        images,labels = images.to(device), labels.to(device)
        logps = model.forward(images)
        # get the loass for the batch
        loss = criterion(logps, labels)
        test_loss += loss.item()
        ps = torch.exp(logps)
        top_p, top_class = ps.topk(1,dim=1)
        equals = top_class == labels.view(*top_class.shape)
        test_accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
print("Test loss is {} .... Test accuracy is {}%".format(test_loss/len(testloader),(test_accuracy/len(testloader))*100))
# Out:
# Test loss is 0.46315224124835086 .... Test accuracy is 86.02469838582553%

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
# TODO: Save the checkpoint 
model_dir = "flower_model_checkpoint_epochs_10.pth"
model_class_to_idx = train_dataset.class_to_idx
torch.save({
    'model_state_dict':model.state_dict(),
    'optimizer_state_dict':optimizer.state_dict(),
     'class_to_idx':model_class_to_idx
},model_dir)

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_model(check_point_path):
    checkpoint = torch.load(check_point_path)
    # model details
    model.load_state_dict(checkpoint['model_state_dict'])
    # optimizer details
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# %%
load_model('flower_model_checkpoint_epochs_10.pth')

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
from PIL import Image
# TODO: Process a PIL image for use in a PyTorch model
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    pil_image = Image.open(image)
    pil_image = pil_image.resize((256,256))
    # set the crop size
    crop_size = 224
    # Get the details of the image
    width, height = pil_image.size
    # calculate the cropping box
    left = (width - crop_size) / 2
    top = (height - crop_size) / 2 
    right = (width + crop_size) / 2
    bottom = ( height + crop_size ) / 2
    # crop the image
    pil_image = pil_image.crop((left,top,right,bottom))
    
    return pil_image

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
import numpy as np
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(3, 6))
    image = np.array(image)
    
    # Undo preprocessing
    # mean = np.array([0.485, 0.456, 0.406])
    # std = np.array([0.229, 0.224, 0.225])
    # image = std * image + mean
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    # image = np.clip(image, 0, 1)
    ax1.set_title("rose")
    ax1.imshow(image)
    plt.title(title)
    ax1.axis('off')
    return ax2

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    # load the image and resize
    image = process_image(image_path)
    # dsiplay the image
    ax=imshow(image)
    # TODO: Implement the code to predict the class from an image file
    # push the model to device
    model.to(device)
    # switch to evaluation mode
    model.eval()
    # convert pil image to numpy then to torch tensor and reshape to fit model input shape
    input_image = torch.from_numpy(np.array(image)).view(1,3,224,224)
    input_image = input_image.type(torch.FloatTensor).to(device)
    # pass the image to the model
    with torch.no_grad():
        logps = model.forward(input_image)
    # get the probabilities
    ps = torch.exp(logps)
    # get the top class and probs and return
    top_p,top_class = ps.topk(topk,dim=1)
    # convert the classes to names
    # print(top_class[0])
    top_class_numpy = top_class.cpu().numpy()
    classes = top_class_numpy[0]
    names = [cat_to_name[str(c+1)] for c in classes ]
    top_p_numpy = top_p.cpu().numpy()
    # plot the prediction of the image
    probabilities = top_p_numpy[0]
    # ax.set_title(names[0])
    ax.barh(y=np.flip(np.array(names)),width=np.flip(np.array(probabilities)))

    # ax.show()

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
predict("/home/terungwa/msughter/aipnd-project/flowers/test/12/image_03996.jpg",model)
# print(cat_to_name[str(73)])
# [c for c in [1,2,3,4]]
